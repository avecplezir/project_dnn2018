# %%
import torch,torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import numpy as np
from model import Generator, iterate_minibatches, compute_loss, train

# %%
OCTAVE_NUM = 4
NOTE_NUM = 12
TIME_SCALE = 128


class LSTM_discriminator(nn.Module):
    def __init__(self,hidden_size = 1000,last_dim = 3):
        super(self.__class__, self).__init__()
        self.last_dim = last_dim
        self.hidden_size = hidden_size
        self.note_lstm = nn.LSTM(input_size = OCTAVE_NUM*last_dim,hidden_size = hidden_size)
        self.time_lstm = nn.LSTM(input_size = hidden_size,hidden_size = hidden_size)
        self.dense = nn.Linear(hidden_size,1)

    def forward(self,data):
        # data.size() =  (batch_size, TIME_SCALE, NOTE_NUM*OCTAVE_NUM, last_dim)
        # octave_data.size() =  (batch_size, TIME_SCALE, NOTE_NUM,OCTAVE_NUM*last_dim)
        batch_size,_,_,_ = data.size()
        octave_data = data.view(batch_size,TIME_SCALE,NOTE_NUM,OCTAVE_NUM,self.last_dim)\
                          .view(batch_size,TIME_SCALE,NOTE_NUM,OCTAVE_NUM*self.last_dim)
            
        # note_lstm_input.size() = (NOTE_NUM, batch_size*TIME_SCALE,OCTAVE_NUM*last_dim)
        note_lstm_input = octave_data.view(batch_size*TIME_SCALE,NOTE_NUM,OCTAVE_NUM*self.last_dim)\
                                     .transpose(0,1)
        # note_lstm_output.size() = (NOTE_NUM,batch_size*TIME_SCALE,hidden_size)
        note_lstm_output, _ = self.note_lstm(note_lstm_input)
        # time_lstm_input.size() = (TIME_SCALE,batch_size,hidden_size)
        time_lstm_input = note_lstm_output[-1].view(batch_size,TIME_SCALE,self.hidden_size)\
                                          .transpose(0,1)\
        # time_lstm_output.size() = (TIME_SCALE,batch_size,1000)
        time_lstm_output, _  = self.time_lstm(time_lstm_input)
        # dense_input.size() = (batch_size,1000)
        dense_input = time_lstm_output[-1]
        # dense_output.size() = (batch_size,1)
        dense_output = self.dense(dense_input)
        probs = F.sigmoid(dense_output)
        return probs

# %%
# device = torch.device("cuda:4" if torch.cuda.is_available() else "cpu")
# # device = torch.device("cpu")
# discriminator = LSTM_discriminator(hidden_size=10).to(device)
# np_data = np.random.randn(10,TIME_SCALE,NOTE_NUM*OCTAVE_NUM,3)
# data = torch.FloatTensor(np_data).to(device)
# discriminator(data)

# %%
class LSTM_baseline(nn.Module):
    def __init__(self,hidden_size = 1000):
        super(self.__class__, self).__init__()
        self.hidden_size = hidden_size
        self.note_lstm = nn.LSTM(input_size = OCTAVE_NUM*3,hidden_size = hidden_size)
        self.time_lstm = nn.LSTM(input_size = hidden_size,hidden_size = hidden_size)
        self.dense = nn.Linear(hidden_size,1)

    def forward(self,data,_):
        # data.size() =  (batch_size, TIME_SCALE, NOTE_NUM*OCTAVE_NUM, 3)
        # octave_data.size() =  (batch_size, TIME_SCALE, NOTE_NUM,OCTAVE_NUM*3)
        batch_size,_,_,_ = data.size()
        octave_data = data.view(batch_size,TIME_SCALE,NOTE_NUM,OCTAVE_NUM,3)\
                          .view(batch_size,TIME_SCALE,NOTE_NUM,OCTAVE_NUM*3)
            
        # note_lstm_input.size() = (NOTE_NUM, batch_size*TIME_SCALE,OCTAVE_NUM*3)
        note_lstm_input = octave_data.view(batch_size*TIME_SCALE,NOTE_NUM,OCTAVE_NUM*3)\
                                     .transpose(0,1)
        # note_lstm_output.size() = (NOTE_NUM,batch_size*TIME_SCALE,hidden_size)
        note_lstm_output, _ = self.note_lstm(note_lstm_input)
        # time_lstm_input.size() = (TIME_SCALE,batch_size,hidden_size)
        time_lstm_input = note_lstm_output[-1].view(batch_size,TIME_SCALE,self.hidden_size)\
                                          .transpose(0,1)\
        # time_lstm_output.size() = (TIME_SCALE,batch_size,1000)
        time_lstm_output, _  = self.time_lstm(time_lstm_input)
        # dense_input.size() = (batch_size,1000)
        dense_input = time_lstm_output[-1]
        # dense_output.size() = (batch_size,1)
        dense_output = self.dense(dense_input)
        probs = F.sigmoid(dense_output)
        return probs

# %%
# discriminator = LSTM_baseline(hidden_size=1000).to(device)
# np_data = np.random.randn(10,TIME_SCALE,NOTE_NUM*OCTAVE_NUM,3)
# data = torch.FloatTensor(np_data).to(device)
# discriminator(data)

# %%
class BasicGenerator(nn.Module):
    def __init__(self,hidden_size = 1000):
        super(self.__class__, self).__init__()
        self.dense_in = nn.Linear(TIME_SCALE*NOTE_NUM*OCTAVE_NUM*3,hidden_size)
        self.dense_out = nn.Linear(hidden_size,TIME_SCALE*NOTE_NUM*OCTAVE_NUM*3)

    def forward(self,data,_):
        batch_size,_,_,_ = data.size()
        data = data.view(batch_size,-1)
        hid_data = self.dense_in(data)
        out_data = self.dense_out(hid_data)
        output = F.sigmoid(out_data.view(batch_size, TIME_SCALE, NOTE_NUM*OCTAVE_NUM, 3))
        return output

# %%
class BasicDiscriminator(nn.Module):
    def __init__(self,hidden_size = 1000):
        super(self.__class__, self).__init__()
        self.dense_in = nn.Linear(TIME_SCALE*NOTE_NUM*OCTAVE_NUM*3,hidden_size)
        self.dense_out = nn.Linear(hidden_size,1)

    def forward(self,data):
        batch_size,_,_,_ = data.size()
        data = data.view(batch_size,-1)
        hid_data = self.dense_in(data)
        out_data = self.dense_out(hid_data)
        output = F.sigmoid(out_data)
        return output

# %%
def g_loss(p_fake,sound,in_probs,baseline_pred,eps = 1e-8):
#     probs = sound[:,TIME_SCALE//2:,:,:2]*in_probs[:,TIME_SCALE//2:,:,:2]\
#             +(1-sound[:,TIME_SCALE//2:,:,:2])*(1-in_probs[:,TIME_SCALE//2:,:,:2])
    probs = sound[:,:,:,:2]*in_probs[:,:,:,:2]\
            +(1-sound[:,:,:,:2])*(1-in_probs[:,:,:,:2])
    print(p_fake.mean(),probs.mean())
    return -((probs+eps).log().sum(dim =-1).sum(dim =-1).sum(dim =-1)*(p_fake-baseline_pred)).mean()

# -(in_probs[:,:,:,2].mean()-1)
#     return -(p_fake+eps).log().mean()

# loss = g_loss(discriminator(false_example),sound,data_gen,baseline(x_batch,ch_batch))

#,sound.data,data_gen)


def d_loss(p_fake, p_true,eps = 1e-8):
     return -((1-p_fake+eps).log().mean()-(p_true+eps).log().mean())
    
def bl_loss(bl_pred,real_reward):
    return (bl_pred-real_reward).pow(2).mean()

# %%
import torch.utils.data

def sample_sound(data_gen):
    size = data_gen.size()
    rand = torch.rand(*size).cuda()
    sample = (rand<data_gen).type(torch.FloatTensor).cuda()
#     sample[:,:,:,2] = data_gen[:,:,:,2]
    sample[:,:,:,2] = 1
    return sample
    

def train_GAN(generator,discriminator,baseline,X_loader,Y_loader,num_epochs = 3,g_lr = 0.001, d_lr = 0.001,bl_lr = 0.001):
    generator.train()
    discriminator.train()
    g_optimizer = torch.optim.Adam(generator.parameters(),     lr=g_lr)#, betas=(0.5, 0.999))
    d_optimizer = torch.optim.Adam(discriminator.parameters(), lr=d_lr)#, betas=(0.5, 0.999))
    bl_optimizer = torch.optim.Adam(baseline.parameters(), lr=bl_lr)
    
    d_losses = []
    g_losses = []
    bl_losses = []
    for epoch in range(num_epochs):
        for [x_batch,ch_batch],[y_batch] in zip(X_loader,Y_loader):
            x_batch = x_batch.cuda()
            ch_batch = ch_batch.cuda()
            y_batch = y_batch.cuda()
            x_batch[:,:,:,2] = 1
            ch_batch[:,:,:,2] = 1
            y_batch[:,:,:,2] = 1
            # Optimize D

            data_gen = generator(x_batch,ch_batch)
            sound = sample_sound(data_gen).data
            #concat_sound = torch.cat([x_batch[:,1:TIME_SCALE//2+1,:,:],sound[:,TIME_SCALE//2:,:,:]],dim = 1)
            loss = d_loss(discriminator(sound), discriminator(y_batch))
            d_optimizer.zero_grad()
            loss.backward()
#             print(loss.grad)
            d_optimizer.step()
            d_losses.append(loss.data.cpu().numpy())
        
            # Optimize BL
            data_gen = generator(x_batch,ch_batch)
            sound = sample_sound(data_gen).data
            loss = bl_loss(baseline(x_batch,ch_batch),discriminator(sound))
            bl_optimizer.zero_grad()
            loss.backward()
            bl_optimizer.step()
            bl_losses.append(loss.data.cpu().numpy())
            
            # Optimize G
            
            data_gen = generator(x_batch,ch_batch)
            sound = sample_sound(data_gen).data
            #concat_sound = torch.cat([x_batch[:,1:TIME_SCALE//2+1,:,:],sound[:,TIME_SCALE//2:,:,:]],dim = 1)
            loss = g_loss(discriminator(sound),sound,data_gen,baseline(x_batch,ch_batch))#,sound.data,data_gen)
            g_optimizer.zero_grad()
            loss.backward()
#             print(loss.grad)
            g_optimizer.step()
            g_losses.append(loss.data.cpu().numpy())
    return generator,discriminator,baseline,np.array(g_losses),np.array(d_losses),np.array(bl_losses)

# %%
from dataset import load_all
from constants import *

styles= [['data/Bach1']]
train_data, train_labels = load_all(styles, BATCH_SIZE, TIME_SCALE)
N = 2500
X_tr = train_data[0][:N]
y_tr = train_labels[0][:N]
# X_te = train_data[0][N:2*N]
train_data[0].shape,
# X_te.shape,y_tr.shape,N
#y_te = train_labels[0][-1:]
# Out:
# ((81, 128, 48, 3),)

# %%
X_loader = torch.utils.data.DataLoader(\
            torch.utils.data.TensorDataset(\
            *(torch.FloatTensor(X_tr),
            torch.FloatTensor(y_tr))),\
            batch_size=10,shuffle=True)
# Y_loader = torch.utils.data.DataLoader(\
#             torch.utils.data.TensorDataset(\
#             torch.FloatTensor(X_te)),\
#             batch_size=10,shuffle=True)

# %%
import torch.utils.data

    

def train_GAN2(generator,discriminator,baseline,X_loader,num_epochs = 3,g_lr = 0.001, d_lr = 0.001,bl_lr = 0.001):
    generator.train()
    discriminator.train()
    g_optimizer = torch.optim.Adam(generator.parameters(),     lr=g_lr)#, betas=(0.5, 0.999))
    d_optimizer = torch.optim.Adam(discriminator.parameters(), lr=d_lr,weight_decay = 1)#, betas=(0.5, 0.999))
    bl_optimizer = torch.optim.Adam(baseline.parameters(), lr=bl_lr)
    
    d_losses = []
    g_losses = []
    bl_losses = []
    for epoch in range(num_epochs):
        for x_batch,ch_batch in X_loader:
            x_batch = x_batch.cuda()
            ch_batch = ch_batch.cuda()

            x_batch[:,:,:,2] = 1
            ch_batch[:,:,:,2] = 1

            # Optimize D
#             print(1)

            data_gen = generator(x_batch,ch_batch)
            sound = sample_sound(data_gen).data
            #concat_sound = torch.cat([x_batch[:,1:TIME_SCALE//2+1,:,:],sound[:,TIME_SCALE//2:,:,:]],dim = 1)
            false_example = torch.cat([sound,x_batch],dim = -1)
            true_example = torch.cat([x_batch,ch_batch],dim = -1)
            loss = d_loss(discriminator(false_example), discriminator(true_example))
            d_optimizer.zero_grad()
            loss.backward()
#             print(loss.grad)
            d_optimizer.step()
            d_losses.append(loss.data.cpu().numpy())
        
            # Optimize BL
            data_gen = generator(x_batch,ch_batch)
#             sound = sample_sound(data_gen).data
            false_example = torch.cat([sound,x_batch],dim = -1)
            loss = bl_loss(baseline(x_batch,ch_batch),discriminator(false_example))
            bl_optimizer.zero_grad()
            loss.backward()
            bl_optimizer.step()
            bl_losses.append(loss.data.cpu().numpy())
            
            # Optimize G
            
            data_gen = generator(x_batch,ch_batch)
#             sound = sample_sound(data_gen).data
            #concat_sound = torch.cat([x_batch[:,1:TIME_SCALE//2+1,:,:],sound[:,TIME_SCALE//2:,:,:]],dim = 1)
            false_example = torch.cat([sound,x_batch],dim = -1)
            loss = g_loss(discriminator(false_example),sound,data_gen,baseline(x_batch,ch_batch))#,sound.data,data_gen)
            g_optimizer.zero_grad()
            loss.backward()
#             print(loss.grad)
            g_optimizer.step()
            g_losses.append(loss.data.cpu().numpy())
    return generator,discriminator,baseline,np.array(g_losses),np.array(d_losses),np.array(bl_losses)

# %%
generator = Generator().cuda()
discriminator = LSTM_discriminator(hidden_size=100, last_dim=6).cuda()
#     # generator = BasicGenerator().cuda()
baseline = LSTM_baseline(hidden_size=10).cuda()
# discriminator = BasicDiscriminator().cuda()
generator,discriminator,baseline,g_losses,d_losses,bl_losses =\
                    train_GAN2(generator,discriminator,baseline,\
                            X_loader,num_epochs = 50, g_lr = 1*1e-2,d_lr=1*1e-2, bl_lr = 1*1e-3)
# Out:
# tensor(0.4851, device='cuda:0') tensor(0.5002, device='cuda:0')
# tensor(0.4766, device='cuda:0') tensor(0.5361, device='cuda:0')
# tensor(0.4714, device='cuda:0') tensor(0.6574, device='cuda:0')
# tensor(0.4686, device='cuda:0') tensor(0.8271, device='cuda:0')
# tensor(0.4669, device='cuda:0') tensor(0.9043, device='cuda:0')
# tensor(0.4660, device='cuda:0') tensor(0.9231, device='cuda:0')
# tensor(0.4655, device='cuda:0') tensor(0.9484, device='cuda:0')
# tensor(0.4651, device='cuda:0') tensor(0.9484, device='cuda:0')
# tensor(0.4645, device='cuda:0') tensor(0.9512, device='cuda:0')
# tensor(0.4637, device='cuda:0') tensor(0.9687, device='cuda:0')
# tensor(0.4627, device='cuda:0') tensor(0.9772, device='cuda:0')
# tensor(0.4614, device='cuda:0') tensor(0.9817, device='cuda:0')
# tensor(0.4599, device='cuda:0') tensor(0.9852, device='cuda:0')
# tensor(0.4581, device='cuda:0') tensor(0.9878, device='cuda:0')
# tensor(0.4562, device='cuda:0') tensor(0.9885, device='cuda:0')
# tensor(0.4541, device='cuda:0') tensor(0.9897, device='cuda:0')
# tensor(0.4518, device='cuda:0') tensor(0.9920, device='cuda:0')
# tensor(0.4496, device='cuda:0') tensor(0.9923, device='cuda:0')
# tensor(0.4473, device='cuda:0') tensor(0.9942, device='cuda:0')
# tensor(0.4450, device='cuda:0') tensor(0.9952, device='cuda:0')
# tensor(0.4427, device='cuda:0') tensor(0.9958, device='cuda:0')
# tensor(0.4404, device='cuda:0') tensor(0.9967, device='cuda:0')
# tensor(0.4381, device='cuda:0') tensor(0.9975, device='cuda:0')
# tensor(0.4358, device='cuda:0') tensor(0.9980, device='cuda:0')
# tensor(0.4336, device='cuda:0') tensor(0.9983, device='cuda:0')
# tensor(0.4314, device='cuda:0') tensor(0.9985, device='cuda:0')
# tensor(0.4292, device='cuda:0') tensor(0.9989, device='cuda:0')
# tensor(0.4270, device='cuda:0') tensor(0.9987, device='cuda:0')
# tensor(0.4249, device='cuda:0') tensor(0.9988, device='cuda:0')
# tensor(0.4228, device='cuda:0') tensor(0.9987, device='cuda:0')
# tensor(0.4207, device='cuda:0') tensor(0.9989, device='cuda:0')
# tensor(0.4186, device='cuda:0') tensor(0.9989, device='cuda:0')
# tensor(0.4165, device='cuda:0') tensor(0.9990, device='cuda:0')
# tensor(0.4144, device='cuda:0') tensor(0.9990, device='cuda:0')
# tensor(0.4122, device='cuda:0') tensor(0.9991, device='cuda:0')
# tensor(0.4101, device='cuda:0') tensor(0.9987, device='cuda:0')
# tensor(0.4080, device='cuda:0') tensor(0.9989, device='cuda:0')
# tensor(0.4059, device='cuda:0') tensor(0.9991, device='cuda:0')
# tensor(0.4038, device='cuda:0') tensor(0.9991, device='cuda:0')
# tensor(0.4018, device='cuda:0') tensor(0.9991, device='cuda:0')
# tensor(0.3997, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.3977, device='cuda:0') tensor(0.9991, device='cuda:0')
# tensor(0.3957, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.3938, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.3918, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3899, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.3880, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3861, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3842, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3823, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3805, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3787, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3768, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3750, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3733, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3715, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3698, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3680, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3663, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3646, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3630, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3613, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3597, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.3581, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3565, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3549, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3534, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3519, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3504, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3489, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3474, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3459, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3445, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3431, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3417, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3403, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3390, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3376, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3363, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3350, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3337, device='cuda:0') tensor(0.9991, device='cuda:0')
# tensor(0.3325, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3312, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3300, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3288, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3276, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3264, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3252, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3241, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3230, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.3219, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3208, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3197, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3186, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3176, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3166, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3156, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3146, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3136, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3126, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3117, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3108, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.3099, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3090, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3081, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3072, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3064, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3055, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3047, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3039, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.3031, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3023, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.3016, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3008, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.3001, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2994, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2986, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2979, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2973, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2966, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2959, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2953, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2946, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2940, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2934, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2928, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2922, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2917, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2911, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2905, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2900, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2895, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2889, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2884, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2879, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2875, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2870, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2865, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2860, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2856, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2852, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2847, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2843, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2839, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2835, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2831, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2827, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2824, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2820, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2816, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2813, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2809, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2806, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2803, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2800, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2796, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2793, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2790, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2788, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2785, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2782, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2779, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2777, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2774, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2772, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2769, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2767, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2764, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2762, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2760, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2758, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2756, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2754, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2752, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2750, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2748, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2746, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2744, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2743, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2741, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2739, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2738, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2736, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2735, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2733, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2732, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2730, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2729, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2728, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2726, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2725, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2724, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2723, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2722, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2721, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2720, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2719, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2717, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2717, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2716, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2715, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2714, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2713, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2712, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2711, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2710, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2710, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2709, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2708, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2708, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2707, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2706, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2706, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2705, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2704, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2704, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2703, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2703, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2702, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2702, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2701, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2701, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2700, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2700, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2700, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2699, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2699, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2698, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2698, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2698, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2697, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2697, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2697, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2696, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2696, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2696, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2696, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2695, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2695, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2695, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2695, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2694, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2694, device='cuda:0') tensor(0.9990, device='cuda:0')
# tensor(0.2694, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2694, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2694, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2693, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2693, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2693, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2693, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2693, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2693, device='cuda:0') tensor(0.9996, device='cuda:0')
# tensor(0.2692, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2692, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2692, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2692, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2692, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2692, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2692, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2692, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2691, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2691, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2691, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2691, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2691, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2691, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2691, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2691, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2691, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2691, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2691, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2691, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2691, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9996, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2690, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9990, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9995, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9990, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9990, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9991, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9991, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9991, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9991, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9996, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9991, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9991, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9994, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9992, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# tensor(0.2689, device='cuda:0') tensor(0.9993, device='cuda:0')
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-35-4be67f698ba6> in <module>()
#       4 baseline = LSTM_baseline(hidden_size=10).cuda()
#       5 # discriminator = BasicDiscriminator().cuda()
# ----> 6 generator,discriminator,baseline,g_losses,d_losses,bl_losses =                    train_GAN2(generator,discriminator,baseline,                            X_loader,num_epochs = 50, g_lr = 1*1e-2,d_lr=1*1e-2, bl_lr = 1*1e-3)
#
# <ipython-input-33-595b4c0cfae8> in train_GAN2(generator, discriminator, baseline, X_loader, num_epochs, g_lr, d_lr, bl_lr)
#      40 #             sound = sample_sound(data_gen).data
#      41             false_example = torch.cat([sound,x_batch],dim = -1)
# ---> 42             loss = bl_loss(baseline(x_batch,ch_batch),discriminator(false_example))
#      43             bl_optimizer.zero_grad()
#      44             loss.backward()
#
# /opt/miniconda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# <ipython-input-23-dc5c9b1c0d9f> in forward(self, data)
#      25         # time_lstm_input.size() = (TIME_SCALE,batch_size,hidden_size)
#      26         time_lstm_input = note_lstm_output[-1].view(batch_size,TIME_SCALE,self.hidden_size)                                          .transpose(0,1)        # time_lstm_output.size() = (TIME_SCALE,batch_size,1000)
# ---> 27         time_lstm_output, _  = self.time_lstm(time_lstm_input)
#      28         # dense_input.size() = (batch_size,1000)
#      29         dense_input = time_lstm_output[-1]
#
# /opt/miniconda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /opt/miniconda/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     190             flat_weight=flat_weight
#     191         )
# --> 192         output, hidden = func(input, self.all_weights, hx, batch_sizes)
#     193         if is_packed:
#     194             output = PackedSequence(output, batch_sizes)
#
# /opt/miniconda/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, *fargs, **fkwargs)
#     321             func = decorator(func)
#     322
# --> 323         return func(input, *fargs, **fkwargs)
#     324
#     325     return forward
#
# /opt/miniconda/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, weight, hx, batch_sizes)
#     285             batch_first, dropout, train, bool(bidirectional),
#     286             list(batch_sizes.data) if variable_length else (),
# --> 287             dropout_ts)
#     288
#     289         if cx is not None:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
plt.plot(g_losses,label = "Generator loss")
plt.legend()
plt.show()
plt.plot(d_losses,label = "Discriminator loss")
plt.legend()
plt.show()
plt.plot(bl_losses,label = "Baseline loss")
plt.legend()
plt.show()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-21-dab592e2e3ee> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(g_losses,label = "Generator loss")
#       3 plt.legend()
#       4 plt.show()
#       5 plt.plot(d_losses,label = "Discriminator loss")
#
# NameError: name 'g_losses' is not defined

# %%
g_losses
# Out:
# array([18.420675, 18.420675, 18.420675, 18.420675, 18.420675, 18.420675,
#        18.420675, 18.420675, 18.420675, 18.420675, 18.420675, 18.420675,
#        18.420675, 18.420675, 18.420675, 18.420675, 18.420675, 18.420675,
#        18.420675, 18.420675, 18.420675, 18.420675, 18.420675, 18.420675,
#        18.420675, 18.420675, 18.420675, 18.420675, 18.420675, 18.420675,
#        18.420675, 18.420675, 18.420675, 18.420675, 18.420675, 18.420675,
#        18.420675, 18.420675, 18.420675, 18.420675, 18.420675, 18.420675,
#        18.420675, 18.420675, 18.420675, 18.420675, 18.420675, 18.420675,
#        18.420675, 18.420675], dtype=float32)

# %%
from generate import write_file, generate
# import gc
# torch.cuda.empty_cache()
# gc.collect() 

# with torch.cuda.device(GPU):
write_file('output/canonical_test', generate(generator, 4))
# Out:
#   2%|▏         | 1/64 [00:00<00:09,  6.36it/s]
# Generating with no styles:
# 100%|██████████| 64/64 [00:05<00:00, 10.71it/s]
# Writing file out/samples/output/canonical_test_0.mid
